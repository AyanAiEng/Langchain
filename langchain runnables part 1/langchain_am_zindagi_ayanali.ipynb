# %%
import random

# this is a dummny class made just to learn and explain

class Naklillm():
    def __init__(self):
        print("llm created")

    def predict(self,promppt):

        response_list = [
            "Delhi is the capital of India",
            "IPL is a cricket league",
            "AI stands for Artificial Intelligence"
        ]

        return {"responce":random.choice(response_list)}

# %%
llm = Naklillm()
# Out:
# llm created

# %%
llm.predict("what is the cpaital of india")
# Out:
# {'responce': 'AI stands for Artificial Intelligence'}

# %%
class NakliPromptTemplate:
    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self, input_dict):
        # This takes the dictionary and plugs values into the {curly braces}
        return self.template.format(**input_dict)

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# Make sure to provide ALL variables required by the template
prompt_text = template.format({"topic": "AI", "length": "short"})
print(prompt_text)
# Output: Write a short poem about AI
# Out:
# Write a short poem about AI

# %%
prompt = template.format({'length':'short','topic':'india'})

# %%
prompt
# Out:
# 'Write a short poem about india'

# %%
class LLMchain:
    def __init__(self,llm,prompt):
        self.llm = llm
        self.prompt = prompt
    def run(self,input_dict):
        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)
        return result["responce"]

# %%
template = NakliPromptTemplate(
    template='Write a {length} poem about {topic}',
    input_variables=['length', 'topic']
)

# %%
llm = Naklillm()
# Out:
# llm created

# %%
chain = LLMchain(llm, template)

# %%
chain.run({'length':'short', 'topic': 'india'})
# Out:
# 'Delhi is the capital of India'
